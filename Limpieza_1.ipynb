# %% [markdown]
# # **LIMPIEZA 1**
# Todos numéricos con media.
#
# Strings con "Sin información".
#
# Eliminamos columnas con más de 20,000 Nas

# %%
#Librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga y visualización de archivos
cuentas = pd.read_excel("cuentas_credicel.xlsx")

#Para poder ver bases completas cuando necesitamos info
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
cuentas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22735 entries, 0 to 22734
# Data columns (total 37 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   folio               22735 non-null  int64
#  1   tag                 22735 non-null  object
#  2   folio_solicitud     22735 non-null  int64
#  3   fecha               22735 non-null  datetime64[ns]
#  4   marca               22735 non-null  object
#  5   modelo              22735 non-null  object
#  6   plazo               22735 non-null  object
#  7   precio              22735 non-null  float64
#  8   enganche            22735 non-null  float64
#  9   descuento           22735 non-null  float64
#  10  semana              22735 non-null  int64
#  11  monto_financiado    22735 non-null  float64
#  12  costo_total         22735 non-null  int64
#  13  monto_accesorios    22735 non-null  float64
#  14  agente_venta        22735 non-null  object
#  15  dis_venta           22735 non-null  object
#  16  status              22735 non-null  int64
#  17  fraude              22735 non-null  int64
#  18  empresa             22722 non-null  object
#  19  inversion           22735 non-null  int64
#  20  pagos_realizados    22735 non-null  int64
#  21  reautorizacion      22735 non-null  int64
#  22  fecha_ultimo_pago   19379 non-null  datetime64[ns]
#  23  fecha_pago_proximo  19379 non-null  datetime64[ns]
#  24  status_cuenta       18538 non-null  object
#  25  puntos              19140 non-null  float64
#  26  riesgo              20262 non-null  object
#  27  porc_enganche       20262 non-null  float64
#  28  porc_tasa           22735 non-null  float64
#  29  score_buro          22735 non-null  float64
#  30  razones_buro        18230 non-null  object
#  31  semana_actual       18230 non-null  object
#  32  codigo_postal       22050 non-null  object
#  33  Unnamed: 33         859 non-null    object
#  34  Unnamed: 34         1203 non-null   object
#  35  Unnamed: 35         2473 non-null   float64
#  36  Unnamed: 36         1 non-null      float64
# dtypes: datetime64[ns](3), float64(11), int64(9), object(14)
# memory usage: 6.4+ MB

# %%
len(cuentas)
# Out:
# 22735

# %%
cuentas.head(10)
# Out:
#    folio       tag  folio_solicitud               fecha     marca  \
# 0      3  HDNAWQ3A               30 2021-11-12 19:00:05       ZTE
# 1      4  M418YNR4               33 2021-11-12 19:15:58  MOTOROLA
# 2      5  SZ7V3NZT               37 2021-11-13 14:13:08       ZTE
# 3      6  9I08UIQZ               38 2021-11-13 15:45:39       ZTE
# 4      7  JMF4LKYU               44 2021-11-13 16:10:15  MOTOROLA
# 5      8  FOBQ8A27               49 2021-11-13 16:50:50  MOTOROLA
# 6      9  UND81DCF               50 2021-11-13 17:19:13  MOTOROLA
# 7     10  LMC1PBLV               54 2021-11-14 11:19:51  MOTOROLA
# 8     11  5SDZN7O1               59 2021-11-14 13:34:57     KODAK
# 9     12  R523EMQT               62 2021-11-14 14:54:23     NOKIA
#
#                          modelo plazo  precio  enganche  descuento  semana  \
# 0            Blade A3 2020 RO B   26S  1949.0     780.0        0.0      81
# 1  LTE XT2097-12 E7I POWER Azul   13S  2999.0    1050.0        0.0     225
# 2            BLADE A3 2020 Gris   13S  1959.0     490.0        0.0     170
# 3            BLADE A3 2020 Gris   13S  1959.0     490.0        0.0     170
# 4                         G10 B   39S  4299.0    1075.0        0.0     178
# 5  LTE XT2097-12 E7I POWER Azul   26S  2999.0     750.0        0.0     156
# 6      E7I POWER 2+32 GB AZUL B   26S  2999.0     900.0        0.0     145
# 7         LTE XT2128-1 G20 Rosa   13S  3999.0    1500.0        0.0     288
# 8          LTE SEREN D60LX Azul   26S  2889.0    1000.0        0.0     131
# 9      NOKIA 2.4 3+64 GB GRIS B   26S  2999.0     750.0        0.0     156
#
#    monto_financiado  costo_total  monto_accesorios  \
# 0            1169.0         2106               0.0
# 1            1949.0         2925               0.0
# 2            1469.0         2210               0.0
# 3            1469.0         2210               0.0
# 4            3224.0         6942               0.0
# 5            2249.0         4056               0.0
# 6            2099.0         3770               0.0
# 7            2499.0         3744               0.0
# 8            1889.0         3406               0.0
# 9            2249.0         4056               0.0
#
#                       agente_venta dis_venta  status  fraude   empresa  \
# 0  Sintia Verenice Tenorio Perez E   mic0437       2       0  microtec
# 1            Alvaro Rafael Pascual    mic015       2       0  microtec
# 2  Sintia Verenice Tenorio Perez E   mic0437       3       0  microtec
# 3       Luz Aylin Hernandez Lopez1   mic0748       2       0  microtec
# 4  Sintia Verenice Tenorio Perez E   mic0437       1       0  microtec
# 5    Karim Hassan Mendez Animas GP   mic0569       2       0  microtec
# 6  Luis Gerardo Almanzar Hernandez   mic0437       2       0  microtec
# 7        Mayra Jazmin Reyes Patino   mic0666       2       0  microtec
# 8  Luis Gerardo Almanzar Hernandez   mic0437       2       0  microtec
# 9        Rita Dalia Morales Flores    mic08q       1       0  microtec
#
#    inversion  pagos_realizados  reautorizacion fecha_ultimo_pago  \
# 0          0                 0               0               NaT
# 1          0                 0               0               NaT
# 2          0                 0               0               NaT
# 3          0                 0               0               NaT
# 4          0                 0               0        2022-03-05
# 5          0                 0               0               NaT
# 6          0                 0               0               NaT
# 7          0                 0               0               NaT
# 8          0                 0               0               NaT
# 9          0                15               0        2022-09-03
#
#   fecha_pago_proximo status_cuenta  puntos     riesgo  porc_enganche  \
# 0                NaT           NaN     NaN        NaN            NaN
# 1                NaT           NaN     NaN        NaN            NaN
# 2                NaT           NaN     NaN  Cancelado            0.0
# 3                NaT           NaN     NaN        NaN            NaN
# 4         2022-03-12          Mora     0.0          0            0.0
# 5                NaT           NaN     NaN        NaN            NaN
# 6                NaT           NaN     NaN        NaN            NaN
# 7                NaT           NaN     NaN        NaN            NaN
# 8                NaT           NaN     NaN        NaN            NaN
# 9         2022-12-06          Mora     0.0          0            0.0
#
#    porc_tasa  score_buro razones_buro semana_actual codigo_postal Unnamed: 33  \
# 0        0.0         0.0            0             0             0         NaN
# 1        0.0         0.0            0             0             0         NaN
# 2        0.0         0.0            0             0           NaN         NaN
# 3        0.0         0.0            0             0             0         NaN
# 4        0.0         0.0          NaN           NaN            74         NaN
# 5        0.0         0.0            0             0             0         NaN
# 6        0.0         0.0            0             0             0         NaN
# 7        0.0         0.0            0             0             0         NaN
# 8        0.0         0.0            0             0             0         NaN
# 9        0.0         0.0          NaN           NaN            74         NaN
#
#   Unnamed: 34  Unnamed: 35  Unnamed: 36
# 0         NaN         26.0          NaN
# 1         NaN         13.0          NaN
# 2          74          NaN          NaN
# 3         NaN         13.0          NaN
# 4         NaN          NaN          NaN
# 5         NaN         26.0          NaN
# 6         NaN         26.0          NaN
# 7         NaN         13.0          NaN
# 8         NaN         26.0          NaN
# 9         NaN          NaN          NaN

# %% [markdown]
# ## **Valores nulos**

# %%
cuentas.isnull().sum().sum()
# Out:
# 115562

# %%
cuentas.isnull().sum()
# Out:
# folio                     0
# tag                       0
# folio_solicitud           0
# fecha                     0
# marca                     0
# modelo                    0
# plazo                     0
# precio                    0
# enganche                  0
# descuento                 0
# semana                    0
# monto_financiado          0
# costo_total               0
# monto_accesorios          0
# agente_venta              0
# dis_venta                 0
# status                    0
# fraude                    0
# empresa                  13
# inversion                 0
# pagos_realizados          0
# reautorizacion            0
# fecha_ultimo_pago      3356
# fecha_pago_proximo     3356
# status_cuenta          4197
# puntos                 3595
# riesgo                 2473
# porc_enganche          2473
# porc_tasa                 0
# score_buro                0
# razones_buro           4505
# semana_actual          4505
# codigo_postal           685
# Unnamed: 33           21876
# Unnamed: 34           21532
# Unnamed: 35           20262
# Unnamed: 36           22734
# dtype: int64

# %%
cuentas1 = cuentas.copy()

# %% [markdown]
# **String *Sin información***

# %%
#Sin información
columnas_string_rellenar = ["empresa", "fecha_ultimo_pago", "fecha_pago_proximo", "status_cuenta", "semana_actual", "razones_buro", "riesgo" , "codigo_postal"]
cuentas1[columnas_string_rellenar] = cuentas1[columnas_string_rellenar].fillna("Sin Información")

# %%
cuentas1.isnull().sum()
# Out:
# folio                     0
# tag                       0
# folio_solicitud           0
# fecha                     0
# marca                     0
# modelo                    0
# plazo                     0
# precio                    0
# enganche                  0
# descuento                 0
# semana                    0
# monto_financiado          0
# costo_total               0
# monto_accesorios          0
# agente_venta              0
# dis_venta                 0
# status                    0
# fraude                    0
# empresa                   0
# inversion                 0
# pagos_realizados          0
# reautorizacion            0
# fecha_ultimo_pago         0
# fecha_pago_proximo        0
# status_cuenta             0
# puntos                 3595
# riesgo                    0
# porc_enganche          2473
# porc_tasa                 0
# score_buro                0
# razones_buro              0
# semana_actual             0
# codigo_postal             0
# Unnamed: 33           21876
# Unnamed: 34           21532
# Unnamed: 35           20262
# Unnamed: 36           22734
# dtype: int64

# %% [markdown]
# **Numéricos con media**

# %%
cuentas1["puntos"] = cuentas1["puntos"].fillna(cuentas["puntos"].mean())
cuentas1["porc_enganche"] = cuentas1["porc_enganche"].fillna(cuentas["porc_enganche"].mean())

# %%
cuentas1.isnull().sum()
# Out:
# folio                     0
# tag                       0
# folio_solicitud           0
# fecha                     0
# marca                     0
# modelo                    0
# plazo                     0
# precio                    0
# enganche                  0
# descuento                 0
# semana                    0
# monto_financiado          0
# costo_total               0
# monto_accesorios          0
# agente_venta              0
# dis_venta                 0
# status                    0
# fraude                    0
# empresa                   0
# inversion                 0
# pagos_realizados          0
# reautorizacion            0
# fecha_ultimo_pago         0
# fecha_pago_proximo        0
# status_cuenta             0
# puntos                    0
# riesgo                    0
# porc_enganche             0
# porc_tasa                 0
# score_buro                0
# razones_buro              0
# semana_actual             0
# codigo_postal             0
# Unnamed: 33           21876
# Unnamed: 34           21532
# Unnamed: 35           20262
# Unnamed: 36           22734
# dtype: int64

# %% [markdown]
# **Eliminación de columnas**

# %%
cuentas1 = cuentas1.drop(["Unnamed: 33", "Unnamed: 34", "Unnamed: 35", "Unnamed: 36"], axis=1)

# %%
#Verificamos nulos
cuentas1.isnull().sum()
# Out:
# folio                 0
# tag                   0
# folio_solicitud       0
# fecha                 0
# marca                 0
# modelo                0
# plazo                 0
# precio                0
# enganche              0
# descuento             0
# semana                0
# monto_financiado      0
# costo_total           0
# monto_accesorios      0
# agente_venta          0
# dis_venta             0
# status                0
# fraude                0
# empresa               0
# inversion             0
# pagos_realizados      0
# reautorizacion        0
# fecha_ultimo_pago     0
# fecha_pago_proximo    0
# status_cuenta         0
# puntos                0
# riesgo                0
# porc_enganche         0
# porc_tasa             0
# score_buro            0
# razones_buro          0
# semana_actual         0
# codigo_postal         0
# dtype: int64

# %%
#Verficación de nulos completos
cuentas1.isnull().sum().sum()
# Out:
# 0

# %%
cuentas1.head(10)
# Out:
#    folio       tag  folio_solicitud               fecha     marca  \
# 0      3  HDNAWQ3A               30 2021-11-12 19:00:05       ZTE
# 1      4  M418YNR4               33 2021-11-12 19:15:58  MOTOROLA
# 2      5  SZ7V3NZT               37 2021-11-13 14:13:08       ZTE
# 3      6  9I08UIQZ               38 2021-11-13 15:45:39       ZTE
# 4      7  JMF4LKYU               44 2021-11-13 16:10:15  MOTOROLA
# 5      8  FOBQ8A27               49 2021-11-13 16:50:50  MOTOROLA
# 6      9  UND81DCF               50 2021-11-13 17:19:13  MOTOROLA
# 7     10  LMC1PBLV               54 2021-11-14 11:19:51  MOTOROLA
# 8     11  5SDZN7O1               59 2021-11-14 13:34:57     KODAK
# 9     12  R523EMQT               62 2021-11-14 14:54:23     NOKIA
#
#                          modelo plazo  precio  enganche  descuento  semana  \
# 0            Blade A3 2020 RO B   26S  1949.0     780.0        0.0      81
# 1  LTE XT2097-12 E7I POWER Azul   13S  2999.0    1050.0        0.0     225
# 2            BLADE A3 2020 Gris   13S  1959.0     490.0        0.0     170
# 3            BLADE A3 2020 Gris   13S  1959.0     490.0        0.0     170
# 4                         G10 B   39S  4299.0    1075.0        0.0     178
# 5  LTE XT2097-12 E7I POWER Azul   26S  2999.0     750.0        0.0     156
# 6      E7I POWER 2+32 GB AZUL B   26S  2999.0     900.0        0.0     145
# 7         LTE XT2128-1 G20 Rosa   13S  3999.0    1500.0        0.0     288
# 8          LTE SEREN D60LX Azul   26S  2889.0    1000.0        0.0     131
# 9      NOKIA 2.4 3+64 GB GRIS B   26S  2999.0     750.0        0.0     156
#
#    monto_financiado  costo_total  monto_accesorios  \
# 0            1169.0         2106               0.0
# 1            1949.0         2925               0.0
# 2            1469.0         2210               0.0
# 3            1469.0         2210               0.0
# 4            3224.0         6942               0.0
# 5            2249.0         4056               0.0
# 6            2099.0         3770               0.0
# 7            2499.0         3744               0.0
# 8            1889.0         3406               0.0
# 9            2249.0         4056               0.0
#
#                       agente_venta dis_venta  status  fraude   empresa  \
# 0  Sintia Verenice Tenorio Perez E   mic0437       2       0  microtec
# 1            Alvaro Rafael Pascual    mic015       2       0  microtec
# 2  Sintia Verenice Tenorio Perez E   mic0437       3       0  microtec
# 3       Luz Aylin Hernandez Lopez1   mic0748       2       0  microtec
# 4  Sintia Verenice Tenorio Perez E   mic0437       1       0  microtec
# 5    Karim Hassan Mendez Animas GP   mic0569       2       0  microtec
# 6  Luis Gerardo Almanzar Hernandez   mic0437       2       0  microtec
# 7        Mayra Jazmin Reyes Patino   mic0666       2       0  microtec
# 8  Luis Gerardo Almanzar Hernandez   mic0437       2       0  microtec
# 9        Rita Dalia Morales Flores    mic08q       1       0  microtec
#
#    inversion  pagos_realizados  reautorizacion    fecha_ultimo_pago  \
# 0          0                 0               0      Sin Información
# 1          0                 0               0      Sin Información
# 2          0                 0               0      Sin Información
# 3          0                 0               0      Sin Información
# 4          0                 0               0  2022-03-05 00:00:00
# 5          0                 0               0      Sin Información
# 6          0                 0               0      Sin Información
# 7          0                 0               0      Sin Información
# 8          0                 0               0      Sin Información
# 9          0                15               0  2022-09-03 00:00:00
#
#     fecha_pago_proximo    status_cuenta     puntos           riesgo  \
# 0      Sin Información  Sin Información  14.081714  Sin Información
# 1      Sin Información  Sin Información  14.081714  Sin Información
# 2      Sin Información  Sin Información  14.081714        Cancelado
# 3      Sin Información  Sin Información  14.081714  Sin Información
# 4  2022-03-12 00:00:00             Mora   0.000000                0
# 5      Sin Información  Sin Información  14.081714  Sin Información
# 6      Sin Información  Sin Información  14.081714  Sin Información
# 7      Sin Información  Sin Información  14.081714  Sin Información
# 8      Sin Información  Sin Información  14.081714  Sin Información
# 9  2022-12-06 00:00:00             Mora   0.000000                0
#
#    porc_enganche  porc_tasa  score_buro     razones_buro    semana_actual  \
# 0        0.90057        0.0         0.0                0                0
# 1        0.90057        0.0         0.0                0                0
# 2        0.00000        0.0         0.0                0                0
# 3        0.90057        0.0         0.0                0                0
# 4        0.00000        0.0         0.0  Sin Información  Sin Información
# 5        0.90057        0.0         0.0                0                0
# 6        0.90057        0.0         0.0                0                0
# 7        0.90057        0.0         0.0                0                0
# 8        0.90057        0.0         0.0                0                0
# 9        0.00000        0.0         0.0  Sin Información  Sin Información
#
#      codigo_postal
# 0                0
# 1                0
# 2  Sin Información
# 3                0
# 4               74
# 5                0
# 6                0
# 7                0
# 8                0
# 9               74

# %% [markdown]
# ## **Outliers**

# %%
fig = plt.figure(figsize =(15, 8))
cuentas1.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
#Separamos columnas
columnas1 = cuentas1.iloc[ : , 7:14]
columnas2 = cuentas1.iloc[ : , [16,17]]
columnas3 = cuentas1.iloc[ : , [19, 20, 21]]
columnas4 = cuentas1.iloc[ : , [25]]
columnas5 = cuentas1.iloc[ : , [27, 28, 29]]

cuentas_cuanti = pd.concat([columnas1, columnas2, columnas3, columnas4, columnas5], axis = 1)
cuentas_cuanti.head()
# Out:
#    precio  enganche  descuento  semana  monto_financiado  costo_total  \
# 0  1949.0     780.0        0.0      81            1169.0         2106
# 1  2999.0    1050.0        0.0     225            1949.0         2925
# 2  1959.0     490.0        0.0     170            1469.0         2210
# 3  1959.0     490.0        0.0     170            1469.0         2210
# 4  4299.0    1075.0        0.0     178            3224.0         6942
#
#    monto_accesorios  status  fraude  inversion  pagos_realizados  \
# 0               0.0       2       0          0                 0
# 1               0.0       2       0          0                 0
# 2               0.0       3       0          0                 0
# 3               0.0       2       0          0                 0
# 4               0.0       1       0          0                 0
#
#    reautorizacion     puntos  porc_enganche  porc_tasa  score_buro
# 0               0  14.081714        0.90057        0.0         0.0
# 1               0  14.081714        0.90057        0.0         0.0
# 2               0  14.081714        0.00000        0.0         0.0
# 3               0  14.081714        0.90057        0.0         0.0
# 4               0   0.000000        0.00000        0.0         0.0

# %%
#Tratamiento con desviación estándar
    #Marcamos límites
y = cuentas_cuanti
Limite_Superior= y.mean() + 2*y.std()
Limite_Inferior= y.mean() - 2*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido precio               6720.050919
# enganche             1879.810360
# descuento             344.968594
# semana                440.107378
# monto_financiado     5269.590744
# costo_total         10471.622939
# monto_accesorios      131.995176
# status                  2.159244
# fraude                  0.601027
# inversion               1.086598
# pagos_realizados       29.597681
# reautorizacion          0.396739
# puntos                 32.949593
# porc_enganche          12.390791
# porc_tasa              16.924431
# score_buro              9.202269
# dtype: float64
# Limite inferior permitido precio              1274.022264
# enganche             -26.935581
# descuento           -188.017109
# semana                35.387322
# monto_financiado     882.682482
# costo_total          927.761710
# monto_accesorios    -105.067640
# status                 0.351510
# fraude                -0.451390
# inversion             -0.613407
# pagos_realizados      -9.236124
# reautorizacion        -0.328650
# puntos                -4.786166
# porc_enganche        -10.589651
# porc_tasa            -13.899997
# score_buro            -9.713432
# dtype: float64

# %%
#Hacemos el cambio a un nuevo data frame
cuanti_cuentas_limpio_out = cuentas_cuanti[(y<=Limite_Superior)&(y>=Limite_Inferior)]
cuanti_cuentas_limpio_out.head()
# Out:
#    precio  enganche  descuento  semana  monto_financiado  costo_total  \
# 0  1949.0     780.0        0.0    81.0            1169.0       2106.0
# 1  2999.0    1050.0        0.0   225.0            1949.0       2925.0
# 2  1959.0     490.0        0.0   170.0            1469.0       2210.0
# 3  1959.0     490.0        0.0   170.0            1469.0       2210.0
# 4  4299.0    1075.0        0.0   178.0            3224.0       6942.0
#
#    monto_accesorios  status  fraude  inversion  pagos_realizados  \
# 0               0.0     2.0     0.0          0               0.0
# 1               0.0     2.0     0.0          0               0.0
# 2               0.0     NaN     0.0          0               0.0
# 3               0.0     2.0     0.0          0               0.0
# 4               0.0     1.0     0.0          0               0.0
#
#    reautorizacion     puntos  porc_enganche  porc_tasa  score_buro
# 0             0.0  14.081714        0.90057        0.0         0.0
# 1             0.0  14.081714        0.90057        0.0         0.0
# 2             0.0  14.081714        0.00000        0.0         0.0
# 3             0.0  14.081714        0.90057        0.0         0.0
# 4             0.0   0.000000        0.00000        0.0         0.0

# %%
#Observamos valores atípicos del data frame
outliers_cuan_cuentas= cuentas_cuanti[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers_cuan_cuentas.head()
# Out:
#    precio  enganche  descuento  semana  monto_financiado  costo_total  \
# 0     NaN       NaN        NaN     NaN               NaN          NaN
# 1     NaN       NaN        NaN     NaN               NaN          NaN
# 2     NaN       NaN        NaN     NaN               NaN          NaN
# 3     NaN       NaN        NaN     NaN               NaN          NaN
# 4     NaN       NaN        NaN     NaN               NaN          NaN
#
#    monto_accesorios  status  fraude  inversion  pagos_realizados  \
# 0               NaN     NaN     NaN        NaN               NaN
# 1               NaN     NaN     NaN        NaN               NaN
# 2               NaN     3.0     NaN        NaN               NaN
# 3               NaN     NaN     NaN        NaN               NaN
# 4               NaN     NaN     NaN        NaN               NaN
#
#    reautorizacion  puntos  porc_enganche  porc_tasa  score_buro
# 0             NaN     NaN            NaN        NaN         NaN
# 1             NaN     NaN            NaN        NaN         NaN
# 2             NaN     NaN            NaN        NaN         NaN
# 3             NaN     NaN            NaN        NaN         NaN
# 4             NaN     NaN            NaN        NaN         NaN

# %%
#Cambiamos nuevo nulos a media
cuanti_cuentas_limpio_out_mean = cuanti_cuentas_limpio_out.copy()
cuanti_cuentas_limpio_out_mean = cuanti_cuentas_limpio_out.fillna(cuanti_cuentas_limpio_out.mean())
cuanti_cuentas_limpio_out_mean.head()
# Out:
#    precio  enganche  descuento  semana  monto_financiado  costo_total  \
# 0  1949.0     780.0        0.0    81.0            1169.0       2106.0
# 1  2999.0    1050.0        0.0   225.0            1949.0       2925.0
# 2  1959.0     490.0        0.0   170.0            1469.0       2210.0
# 3  1959.0     490.0        0.0   170.0            1469.0       2210.0
# 4  4299.0    1075.0        0.0   178.0            3224.0       6942.0
#
#    monto_accesorios    status  fraude  inversion  pagos_realizados  \
# 0               0.0  2.000000     0.0          0               0.0
# 1               0.0  2.000000     0.0          0               0.0
# 2               0.0  1.243346     0.0          0               0.0
# 3               0.0  2.000000     0.0          0               0.0
# 4               0.0  1.000000     0.0          0               0.0
#
#    reautorizacion     puntos  porc_enganche  porc_tasa  score_buro
# 0             0.0  14.081714        0.90057        0.0         0.0
# 1             0.0  14.081714        0.90057        0.0         0.0
# 2             0.0  14.081714        0.00000        0.0         0.0
# 3             0.0  14.081714        0.90057        0.0         0.0
# 4             0.0   0.000000        0.00000        0.0         0.0

# %%
#Para crear el dataframe de cualitativas, solo se "restan" aquellas variables que ya ocupamos del dataframe de cuantitatuvas
columnas_a_eliminar = cuentas_cuanti.columns
cuentas_cuali = cuentas1.drop(columns=columnas_a_eliminar)
cuentas_cuali.columns
# Out:
# Index(['folio', 'tag', 'folio_solicitud', 'fecha', 'marca', 'modelo', 'plazo',
#        'agente_venta', 'dis_venta', 'empresa', 'fecha_ultimo_pago',
#        'fecha_pago_proximo', 'status_cuenta', 'riesgo', 'razones_buro',
#        'semana_actual', 'codigo_postal'],
#       dtype='object')

# %%
#Volvemos a observar en diagrama de cajas
fig = plt.figure(figsize =(15, 8))
cuanti_cuentas_limpio_out_mean.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe Limpio")
plt.show()

# %% [markdown]
# **Juntamos y guardamos nueva base 1**

# %%
cuentas_final1 = pd.concat([cuanti_cuentas_limpio_out_mean, cuentas_cuali])
cuentas_final1.to_csv("Credicel Limpio1.csv")
